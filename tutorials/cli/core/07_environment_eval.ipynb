# %% [markdown]
# # Core 07 - Environment y Eval (CLI)
#
# Notebook CLI paralelo a `tutorials/core/07_environment_eval.ipynb`.
#
# **Objetivo:** Ejecutar un episodio y evaluar un Executable.
#
# Este notebook no llama factories de Agentic Systems directamente: ejecuta el
# entrypoint CLI real, conserva la salida Rich y valida después el JSON del mismo
# contrato.

# %% [markdown]
# ## Cómo se ejecuta
#
# La forma portable es `python -m agentic_systems.cli ...`. Después de instalar
# el wheel, el entrypoint equivalente es `agentic-systems ...`.

# %%
from __future__ import annotations

import json
import os
import subprocess
import sys
from pathlib import Path


def _repo_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in (current, *current.parents):
        if (candidate / "pyproject.toml").is_file():
            return candidate
    raise RuntimeError("No se encontró la raíz del repositorio.")


ROOT = _repo_root()
CLI = [sys.executable, "-m", "agentic_systems.cli"]


def run_cli(*args: str, expected: int = 0) -> str:
    env = os.environ.copy()
    source_path = str(ROOT / "src")
    env["PYTHONPATH"] = (
        source_path
        if not env.get("PYTHONPATH")
        else source_path + os.pathsep + env["PYTHONPATH"]
    )
    command = [*CLI, *args]
    completed = subprocess.run(
        command,
        cwd=ROOT,
        env=env,
        text=True,
        encoding="utf-8",
        errors="replace",
        capture_output=True,
        check=False,
    )
    print("$ " + " ".join(command))
    if completed.stdout:
        print(completed.stdout, end="")
    if completed.stderr:
        print(completed.stderr, end="")
    assert completed.returncode == expected, completed.stderr
    return completed.stdout


def run_cli_json(*args: str) -> dict:
    return json.loads(run_cli(*args, "--json"))


def assert_rich(output: str, title: str) -> None:
    assert title in output
    ascii_box = "+" in output and "|" in output
    unicode_box = "─" in output and "│" in output
    assert ascii_box or unicode_box

# %% [markdown]
# ## 1) Salida humana Rich
#
# La celda conserva stdout y comprueba título y bordes. Esto detecta tablas o
# paneles truncados, además del exit code.

# %%
rich_output = run_cli(*['environment', 'run', '--value', 'cli'])
assert_rich(rich_output, 'Environment Workflow')
# Out:
# $ C:\Python314\python.exe -m agentic_systems.cli environment run --value cli
# +--------------------------- Environment Workflow ----------------------------+
# | {                                                                           |
# |   "observation": {                                                          |
# |     "value": "cli"                                                          |
# |   },                                                                        |
# |   "reset": {                                                                |
# |     "cursor": 0,                                                            |
# |     "done": false,                                                          |
# |     "episode_id": "episode-0",                                              |
# |     "graph_state": null,                                                    |
# |     "history_size": 0,                                                      |
# |     "memory": {},                                                           |
# |     "name": "cli_environment",                                              |
# |     "seed": 0,                                                              |
# |     "step": 0,                                                              |
# |     "total_records": 1,                                                     |
# |     "transition": null                                                      |
# |   },                                                                        |
# |   "reward": 1.0,                                                            |
# |   "scenario": "environment",                                                |
# |   "scenario_api_ids": [                                                     |
# |     "environment",                                                          |
# |     "AgenticEnvironment.reset",                                             |
# |     "AgenticEnvironment.step"                                               |
# |   ],                                                                        |
# |   "step": {                                                                 |
# |     "cursor": 1,                                                            |
# |     "done": true,                                                           |
# |     "episode_id": "episode-0",                                              |
# |     "graph_state": {                                                        |
# |       "action": "cli",                                                      |
# |       "episode": {                                                          |
# |         "id": "episode-0",                                                  |
# |         "row_index": 0,                                                     |
# |         "seed": 0,                                                          |
# |         "step_index": 0,                                                    |
# |         "total_records": 1                                                  |
# |       },                                                                    |
# |       "memory": {},                                                         |
# |       "output": {                                                           |
# |         "action": "cli",                                                    |
# |         "row": {                                                            |
# |           "value": "cli"                                                    |
# |         }                                                                   |
# |       },                                                                    |
# |       "row": {                                                              |
# |         "value": "cli"                                                      |
# |       }                                                                     |
# |     },                                                                      |
# |     "history_size": 1,                                                      |
# |     "memory": {},                                                           |
# |     "name": "cli_environment",                                              |
# |     "seed": 0,                                                              |
# |     "step": 1,                                                              |
# |     "total_records": 1,                                                     |
# |     "transition": {                                                         |
# |       "action": "cli",                                                      |
# |       "episode_id": "episode-0",                                            |
# |       "graph_state": {                                                      |
# |         "action": "cli",                                                    |
# |         "episode": {                                                        |
# |           "id": "episode-0",                                                |
# |           "row_index": 0,                                                   |
# |           "seed": 0,                                                        |
# |           "step_index": 0,                                                  |
# |           "total_records": 1                                                |
# |         },                                                                  |
# |         "memory": {},                                                       |
# |         "output": {                                                         |
# |           "action": "cli",                                                  |
# |           "row": {                                                          |
# |             "value": "cli"                                                  |
# |           }                                                                 |
# |         },                                                                  |
# |         "row": {                                                            |
# |           "value": "cli"                                                    |
# |         }                                                                   |
# |       },                                                                    |
# |       "memory": {},                                                         |
# |       "reward": 1.0,                                                        |
# |       "row": {                                                              |
# |         "value": "cli"                                                      |
# |       },                                                                    |
# |       "step_index": 0,                                                      |
# |       "terminated": true,                                                   |
# |       "truncated": false                                                    |
# |     }                                                                       |
# |   },                                                                        |
# |   "summary": {                                                              |
# |     "episode_id": "episode-0",                                              |
# |     "name": "cli_environment",                                              |
# |     "ok": true,                                                             |
# |     "reward_total": 1.0,                                                    |
# |     "steps": [                                                              |
# |       {                                                                     |
# |         "done": true,                                                       |
# |         "reward": 1.0,                                                      |
# |         "row": {                                                            |
# |           "value": "cli"                                                    |
# |         },                                                                  |
# |         "step": 0                                                           |
# |       }                                                                     |
# |     ],                                                                      |
# |     "steps_done": 1,                                                        |
# |     "total_records": 1                                                      |
# |   },                                                                        |
# |   "terminated": true,                                                       |
# |   "truncated": false,                                                       |
# |   "workflow": "environment"                                                 |
# | }                                                                           |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 2) Contrato de máquina
#
# La misma ruta se ejecuta con `--json` para afirmar campos y cardinalidad sin
# parsear la presentación Rich.

# %%
payload = run_cli_json(*['eval', 'run', '--value', 'cli'])
assert payload["report"]["ok"] is True
payload
# Out:
# $ C:\Python314\python.exe -m agentic_systems.cli eval run --value cli --json
# {
#   "report": {
#     "cases": [
#       {
#         "expected": {
#           "data_contains": {
#             "value": "cli"
#           },
#           "must_call": [
#             "cli_echo"
#           ]
#         },
#         "input": {
#           "input": {
#             "value": "cli"
#           },
#           "tool": "cli_echo"
#         },
#         "name": "cli_echo",
#         "ok": true,
#         "result": {
#           "children": [],
#           "data": {
#             "ok": true,
#             "tool": "cli_echo",
#             "value": "cli"
#           },
#           "engine": "python-runtime",
#           "errors": [],
#           "execution_id": null,
#           "final": {
#             "ok": true,
#             "tool": "cli_echo",
#             "value": "cli"
#           },
#           "messages": [],
#           "meta": {
#             "agent_name": "cli_python-runtime_native",
#             "execution_engine": "python-runtime",
#             "framework": "native",
#             "framework_adapter": "native",
#             "framework_config": {
#               "agent_kwargs": {},
#               "name": "native",
#               "run_kwargs": {}
#             },
#             "framework_requested": "native",
#             "input": {
#               "input": {
#                 "value": "cli"
#               },
#               "tool": "cli_echo"
#             },
#             "planned_tool_calls": 1,
#             "requested_engine": "python-runtime",
#             "runtime": {
#               "allow_python_fallback": false,
#               "endpoint": null,
#               "metadata": {},
#               "model_id": "python-runtime",
#               "provider": "python-runtime",
#               "provider_priority": [
#                 "bedrock-runtime",
#                 "openai-runtime",
#                 "vllm-runtime",
#                 "ollama-runtime"
#               ],
#               "region_name": null,
#               "scheduler": {
#                 "backoff_s": 0.0,
#                 "max_concurrency": 1,
#                 "max_retries": 0,
#                 "max_tool_calls": 5,
#                 "max_turns": 6,
#                 "timeout_s": 60.0
#               }
#             },
#             "runtime_engine": "python-runtime",
#             "scheduler": {
#               "backoff_s": 0.0,
#               "max_concurrency": 1,
#               "max_retries": 0,
#               "max_tool_calls": 5,
#               "max_turns": 6,
#               "timeout_s": 60.0
#             },
#             "scheduler_execution": {
#               "attempts": 1,
#               "latency_ms": 6.859,
#               "retries": 0,
#               "scheduler": {
#                 "backoff_s": 0.0,
#                 "max_concurrency": 1,
#                 "max_retries": 0,
#                 "max_tool_calls": 5,
#                 "max_turns": 6,
#                 "timeout_s": 60.0
#               },
#               "timed_out": false
#             },
#             "source_result_type": "PythonRuntimeProvider",
#             "tool_count": 1
#           },
#           "mode": "eval",
#           "model": "python-runtime",
#           "ok": true,
#           "parent_execution_id": null,
#           "raw_responses": [],
#           "text": "cli_echo -> {\"value\": \"cli\"}",
#           "tool_events": [
#             {
#               "duration_ms": null,
#               "error": null,
#               "id": "tool-9f1a48454a114f62b27af5004842b1c3",
#               "input": {
#                 "value": "cli"
#               },
#               "meta": {},
#               "name": "cli_echo",
#               "ok": true,
#               "output": {
#                 "data": {
#                   "value": "cli"
#                 }
#               }
#             }
#           ],
#           "trace_schema_version": "agentic_systems.trace.v1",
#           "usage": {
#             "scheduler": {
#               "attempts": 1,
#               "latency_ms": 6.859,
#               "retries": 0,
#               "timed_out": false
#             }
#           },
#           "validation": {
#             "issues": [],
#             "ok": true
#           }
#         },
#         "validation": {
#           "issues": [],
#           "ok": true
#         }
#       }
#     ],
#     "failed": 0,
#     "ok": true,
#     "pass_rate": 1.0,
#     "passed": 1,
#     "reproducibility": {
#       "classification": "deterministic",
#       "conditions": [
#         "same ordered cases and inputs",
#         "same Agentic Systems, dependency, runtime, and provider configuration",
#         "all tools and external side effects deterministic or replayed",
#         "agent, graph, scorer, and provider contain no uncontrolled randomness"
#       ],
#       "replayable": true,
#       "schema_version": "agentic_systems.eval-reproducibility.v1",
#       "seed": 0
#     },
#     "schema_version": "agentic_systems.eval-report.v1",
#     "total": 1
#   },
#   "scenario": "eval",
#   "scenario_api_ids": [
#     "eval",
#     "Evaluator.run",
#     "EvalReport"
#   ],
#   "workflow": "eval"
# }
# {'report': {'cases': [{'expected': {'data_contains': {'value': 'cli'},
#      'must_call': ['cli_echo']},
#     'input': {'input': {'value': 'cli'}, 'tool': 'cli_echo'},
#     'name': 'cli_echo',
#     'ok': True,
#     'result': {'children': [],
#      'data': {'ok': True, 'tool': 'cli_echo', 'value': 'cli'},
#      'engine': 'python-runtime',
#      'errors': [],
#      'execution_id': None,
#      'final': {'ok': True, 'tool': 'cli_echo', 'value': 'cli'},
#      'messages': [],
#      'meta': {'agent_name': 'cli_python-runtime_native',
#       'execution_engine': 'python-runtime',
#       'framework': 'native',
#       'framework_adapter': 'native',
#       'framework_config': {'agent_kwargs': {},
#        'name': 'native',
#        'run_kwargs': {}},
#       'framework_requested': 'native',
#       'input': {'input': {'value': 'cli'}, 'tool': 'cli_echo'},
#       'planned_tool_calls': 1,
#       'requested_engine': 'python-runtime',
#       'runtime': {'allow_python_fallback': False,
#        'endpoint': None,
#        'metadata': {},
#        'model_id': 'python-runtime',
#        'provider': 'python-runtime',
#        'provider_priority': ['bedrock-runtime',
#         'openai-runtime',
#         'vllm-runtime',
#         'ollama-runtime'],
#        'region_name': None,
#        'scheduler': {'backoff_s': 0.0,
#         'max_concurrency': 1,
#         'max_retries': 0,
#         'max_tool_calls': 5,
#         'max_turns': 6,
#         'timeout_s': 60.0}},
#       'runtime_engine': 'python-runtime',
#       'scheduler': {'backoff_s': 0.0,
#        'max_concurrency': 1,
#        'max_retries': 0,
#        'max_tool_calls': 5,
#        'max_turns': 6,
#        'timeout_s': 60.0},
#       'scheduler_execution': {'attempts': 1,
#        'latency_ms': 6.859,
#        'retries': 0,
#        'scheduler': {'backoff_s': 0.0,
#         'max_concurrency': 1,
#         'max_retries': 0,
#         'max_tool_calls': 5,
#         'max_turns': 6,
#         'timeout_s': 60.0},
#        'timed_out': False},
#       'source_result_type': 'PythonRuntimeProvider',
#       'tool_count': 1},
#      'mode': 'eval',
#      'model': 'python-runtime',
#      'ok': True,
#      'parent_execution_id': None,
#      'raw_responses': [],
#      'text': 'cli_echo -> {"value": "cli"}',
#      'tool_events': [{'duration_ms': None,
#        'error': None,
#        'id': 'tool-9f1a48454a114f62b27af5004842b1c3',
#        'input': {'value': 'cli'},
#        'meta': {},
#        'name': 'cli_echo',
#        'ok': True,
#        'output': {'data': {'value': 'cli'}}}],
#      'trace_schema_version': 'agentic_systems.trace.v1',
#      'usage': {'scheduler': {'attempts': 1,
#        'latency_ms': 6.859,
#        'retries': 0,
#        'timed_out': False}},
#      'validation': {'issues': [], 'ok': True}},
#     'validation': {'issues': [], 'ok': True}}],
#   'failed': 0,
#   'ok': True,
#   'pass_rate': 1.0,
#   'passed': 1,
#   'reproducibility': {'classification': 'deterministic',
#    'conditions': ['same ordered cases and inputs',
#     'same Agentic Systems, dependency, runtime, and provider configuration',
#     'all tools and external side effects deterministic or replayed',
#     'agent, graph, scorer, and provider contain no uncontrolled randomness'],
#    'replayable': True,
#    'schema_version': 'agentic_systems.eval-reproducibility.v1',
#    'seed': 0},
#   'schema_version': 'agentic_systems.eval-report.v1',
#   'total': 1},
#  'scenario': 'eval',
#  'scenario_api_ids': ['eval', 'Evaluator.run', 'EvalReport'],
#  'workflow': 'eval'}

# %% [markdown]
# ## Resultado e interpretación
#
# Rich responde a lectura humana; JSON responde a automatización. Ambos nacen del
# mismo comando y del mismo escenario público. Un estado `not-run` conserva el
# motivo, pero no cuenta como evidencia live.
