# %% [markdown]
# # 14 - Contrato API 1:1 de Agentic Systems 2.1
#
# ## Objetivo
#
# Verificar de forma ejecutable que Source, API, documentacion, notebooks y pytest comparten exactamente los mismos IDs publicos. Este capitulo cierra el recorrido iniciado por runtimes, tools, skills, agents, systems, environments y evals.
#
#
# **Lugar en el modelo:** este capítulo no añade cómputo; verifica que todas las superficies publicadas describen el mismo producto 2.0.
#
# **Evidencia exigida:** IDs, miembros, escenarios y checksum deben coincidir exactamente con Source y resolverse sin efectos externos.
#
# **Límite de la evidencia:** cobertura contractual prueba presencia y trazabilidad de API; las garantías de comportamiento provienen de los escenarios y tests ejecutables.

# %% [markdown]
# ## Parametros de ejecucion
#
# Este notebook es determinista y offline: no usa credenciales ni llama modelos. La matriz live de providers/frameworks se valida antes.

# %%
import agentic_systems as toolkit

api_coverage = [
    'toolkit.api_contract',
    'toolkit.exercise_api',
    'toolkit.show',
]

# %% [markdown]
# ## Inventario esperado
#
# La lista se genera desde Source. Cambiar un export, miembro, firma o tipo publico exige regenerar y revisar este capitulo.

# %%
EXPECTED_API_IDS = tuple([
  "skill",
  "agent",
  "system",
  "environment",
  "eval",
  "runtime",
  "model_artifact",
  "model_server",
  "provider",
  "framework",
  "scheduler",
  "load_skill",
  "AgenticSystem",
  "AgenticSystem.add",
  "AgenticSystem.agent",
  "AgenticSystem.agents",
  "AgenticSystem.arun",
  "AgenticSystem.compile",
  "AgenticSystem.composition",
  "AgenticSystem.environment",
  "AgenticSystem.eval",
  "AgenticSystem.execute_tool",
  "AgenticSystem.export_tool_specs",
  "AgenticSystem.graph",
  "AgenticSystem.inspect",
  "AgenticSystem.load_skill",
  "AgenticSystem.public_tool_names",
  "AgenticSystem.public_tools",
  "AgenticSystem.run",
  "AgenticSystem.runtime_skills",
  "AgenticSystem.skill",
  "AgenticSystem.skill_names",
  "AgenticSystem.skills",
  "AgenticSystem.tool",
  "AgenticSystem.tool_names",
  "AgenticSystem.toolkit",
  "AgenticSystem.tools",
  "AgenticSystem.toolset",
  "Agent",
  "Agent.arun",
  "Agent.as_async_node",
  "Agent.as_node",
  "Agent.as_tool",
  "Agent.available_tools",
  "Agent.bind",
  "Agent.check",
  "Agent.describe",
  "Agent.eval",
  "Agent.info",
  "Agent.native_agent",
  "Agent.pipeline",
  "Agent.prepare",
  "Agent.run",
  "Agent.run_sync",
  "Agent.tool_names",
  "Agent.validate",
  "Tool",
  "Tool.check",
  "Tool.describe",
  "Tool.identity",
  "Tool.info",
  "Tool.run",
  "ToolSet",
  "ToolSet.add",
  "ToolSet.ref",
  "ToolSet.tool",
  "ToolSet.tool_names",
  "Executable",
  "Executable.run",
  "AsyncExecutable",
  "AsyncExecutable.arun",
  "AsyncExecutable.run",
  "toolset",
  "api_contract",
  "exercise_api",
  "ExecutionPlan",
  "ExecutionPlan.execute",
  "ExecutionPlan.name",
  "CompiledSystem",
  "CompiledSystem.arun",
  "CompiledSystem.entrypoint",
  "CompiledSystem.inspect",
  "CompiledSystem.name",
  "CompiledSystem.plan",
  "CompiledSystem.run",
  "CompiledSystem.units",
  "SequentialPlan",
  "SequentialPlan.execute",
  "SequentialPlan.input_selector",
  "SequentialPlan.name",
  "SequentialPlan.stop_on_error",
  "ParallelPlan",
  "ParallelPlan.execute",
  "ParallelPlan.max_workers",
  "ParallelPlan.name",
  "tool",
  "expect",
  "human_result",
  "Skill",
  "Skill.available_tools",
  "Skill.check",
  "Skill.compose",
  "Skill.composition",
  "Skill.describe",
  "Skill.identity",
  "Skill.info",
  "Skill.instructions",
  "Skill.prompt",
  "Skill.tool",
  "Skill.tool_names",
  "Skill.tools",
  "LoadedSkill",
  "LoadedSkill.manifest",
  "LoadedSkill.path",
  "LoadedSkill.registry",
  "LoadedSkill.runtime_skill",
  "AgentContract",
  "AgentContract.check",
  "AgentContract.coerce",
  "AgentContract.completion",
  "AgentContract.expected_output",
  "AgentContract.expected_tool_outputs",
  "AgentContract.failure_policy",
  "AgentContract.model_post_init",
  "AgentContract.must_call",
  "AgentContract.must_not_call",
  "AgentContract.normalize_completion",
  "AgentContract.normalize_failure_policy",
  "AgentContract.require_no_unresolved_tool_failures",
  "AgentContract.tool_expectation",
  "ContractPolicySpec",
  "ContractPolicySpec.agent_kwargs",
  "ContractPolicySpec.check",
  "ContractPolicySpec.coerce",
  "ContractPolicySpec.contract",
  "ContractPolicySpec.describe",
  "ContractPolicySpec.description",
  "ContractPolicySpec.metadata",
  "ContractPolicySpec.name",
  "ContractPolicySpec.policy",
  "ContractPolicySpec.raise_if_failed",
  "ContractPolicySpec.tags",
  "ContractPolicySpec.to_dict",
  "ContractPolicySpec.validate_name",
  "RunPolicy",
  "RunPolicy.check",
  "RunPolicy.coerce",
  "RunPolicy.finalize",
  "RunPolicy.for_mode",
  "RunPolicy.max_repairs",
  "RunPolicy.max_tokens",
  "RunPolicy.max_tool_calls",
  "RunPolicy.max_turns",
  "RunPolicy.merge",
  "RunPolicy.repair",
  "RunPolicy.strict",
  "RunPolicy.temperature",
  "RunPolicy.tool_choice",
  "RunPolicy.trace",
  "RunPolicy.validate_non_negative_repairs",
  "RunPolicy.validate_optional_positive_ints",
  "RunPolicy.validate_optional_token_limit",
  "RunPolicy.validate_optional_tool_limit",
  "RunPolicy.validate_positive_max_turns",
  "RunPolicy.validate_temperature_range",
  "RunPolicy.validate_tool_choice",
  "validate_contract_policy",
  "RunResult",
  "RunResult.add_child",
  "RunResult.apply_validation",
  "RunResult.check_invariants",
  "RunResult.children",
  "RunResult.compact_trace",
  "RunResult.data",
  "RunResult.engine",
  "RunResult.errors",
  "RunResult.execution_id",
  "RunResult.final",
  "RunResult.from_bedrock_runtime",
  "RunResult.lineage",
  "RunResult.messages",
  "RunResult.meta",
  "RunResult.mode",
  "RunResult.model",
  "RunResult.native_result",
  "RunResult.normalized",
  "RunResult.ok",
  "RunResult.parent_execution_id",
  "RunResult.raise_if_inconsistent",
  "RunResult.raw_responses",
  "RunResult.should_retry",
  "RunResult.text",
  "RunResult.to_dict",
  "RunResult.tool_events",
  "RunResult.trace",
  "RunResult.trace_schema_version",
  "RunResult.usage",
  "RunResult.validate",
  "RunResult.validation",
  "RunResult.walk",
  "LineageMemory",
  "LineageMemory.answer",
  "LineageMemory.compact",
  "LineageMemory.estimated_context_savings",
  "LineageMemory.explain",
  "LineageMemory.from_result",
  "LineageMemory.from_run_result",
  "LineageMemory.goal",
  "LineageMemory.human_text",
  "LineageMemory.metadata",
  "LineageMemory.name",
  "LineageMemory.ok",
  "LineageMemory.question",
  "LineageMemory.schema_version",
  "LineageMemory.steps",
  "LineageMemory.tags",
  "LineageMemory.to_dict",
  "LineageMemory.to_prompt_context",
  "LineageMemory.usage",
  "LineageMemory.validation",
  "LineageStep",
  "LineageStep.compact",
  "LineageStep.evidence",
  "LineageStep.kind",
  "LineageStep.source",
  "LineageStep.step_id",
  "LineageStep.summary",
  "LineageStep.title",
  "LineageStep.why",
  "lineage_memory",
  "LINEAGE_SCHEMA_VERSION",
  "AUTO_PROVIDER_ENV_VAR",
  "DEFAULT_AUTO_PROVIDER_PRIORITY",
  "RuntimeConfig",
  "RuntimeConfig.allow_python_fallback",
  "RuntimeConfig.api_key",
  "RuntimeConfig.coerce",
  "RuntimeConfig.describe",
  "RuntimeConfig.endpoint",
  "RuntimeConfig.metadata",
  "RuntimeConfig.model_id",
  "RuntimeConfig.provider",
  "RuntimeConfig.provider_priority",
  "RuntimeConfig.region_name",
  "RuntimeConfig.scheduler",
  "RuntimeConfig.to_dict",
  "ModelArtifact",
  "ModelArtifact.adapter_path",
  "ModelArtifact.base_model_id",
  "ModelArtifact.metadata",
  "ModelArtifact.model_id",
  "ModelArtifact.quantization",
  "ModelArtifact.revision",
  "ModelArtifact.schema_version",
  "ModelArtifact.supported_schema_version",
  "ModelArtifact.tokenizer_id",
  "ModelServer",
  "ModelServer.health",
  "ModelServer.start",
  "ModelServer.stop",
  "VLLMServerSpec",
  "VLLMServerSpec.api_key",
  "VLLMServerSpec.artifact",
  "VLLMServerSpec.backend",
  "VLLMServerSpec.binary",
  "VLLMServerSpec.enable_auto_tool_choice",
  "VLLMServerSpec.extra_args",
  "VLLMServerSpec.generation_config",
  "VLLMServerSpec.gpu_memory_utilization",
  "VLLMServerSpec.host",
  "VLLMServerSpec.log_path",
  "VLLMServerSpec.max_model_len",
  "VLLMServerSpec.max_num_seqs",
  "VLLMServerSpec.port",
  "VLLMServerSpec.profile",
  "VLLMServerSpec.reasoning_parser",
  "VLLMServerSpec.schema_version",
  "VLLMServerSpec.served_model_name",
  "VLLMServerSpec.startup_timeout_s",
  "VLLMServerSpec.supported_schema_version",
  "VLLMServerSpec.tool_call_parser",
  "VLLMServer",
  "VLLMServer.command",
  "VLLMServer.endpoint",
  "VLLMServer.health",
  "VLLMServer.inspect",
  "VLLMServer.running",
  "VLLMServer.runtime",
  "VLLMServer.start",
  "VLLMServer.stop",
  "EndpointInfo",
  "EndpointInfo.api_key_configured",
  "EndpointInfo.backend",
  "EndpointInfo.base_url",
  "EndpointInfo.model_id",
  "EndpointInfo.owned",
  "EndpointInfo.pid",
  "EndpointInfo.schema_version",
  "EndpointInfo.supported_schema_version",
  "ServerHealth",
  "ServerHealth.detail",
  "ServerHealth.endpoint",
  "ServerHealth.schema_version",
  "ServerHealth.status",
  "ServerHealth.supported_schema_version",
  "ModelProviderConfig",
  "ModelProviderConfig.endpoint",
  "ModelProviderConfig.identity",
  "ModelProviderConfig.metadata",
  "ModelProviderConfig.model_id",
  "ModelProviderConfig.name",
  "ModelProviderConfig.region_name",
  "ModelProviderConfig.to_dict",
  "compatibility_matrix",
  "dependency_target",
  "compatibility_report",
  "normalize_provider_priority",
  "resolve_auto_provider",
  "SchedulerConfig",
  "SchedulerConfig.backoff_s",
  "SchedulerConfig.coerce",
  "SchedulerConfig.execution_limits",
  "SchedulerConfig.max_concurrency",
  "SchedulerConfig.max_retries",
  "SchedulerConfig.max_tool_calls",
  "SchedulerConfig.max_turns",
  "SchedulerConfig.policy_overrides",
  "SchedulerConfig.timeout_s",
  "SchedulerConfig.to_dict",
  "OutputSchema",
  "OutputSchema.aliases",
  "OutputSchema.coerce",
  "OutputSchema.fields",
  "OutputSchema.many",
  "OutputSchema.project",
  "OutputSchema.required",
  "OutputSchema.root_key",
  "final_answer",
  "normalize_output",
  "output_schema",
  "FrameworkConfig",
  "FrameworkConfig.agent_kwargs",
  "FrameworkConfig.coerce",
  "FrameworkConfig.copy_kwargs",
  "FrameworkConfig.inspect",
  "FrameworkConfig.name",
  "FrameworkConfig.reject_reserved_kwargs",
  "FrameworkConfig.run_kwargs",
  "FrameworkConfig.to_dict",
  "FrameworkConfig.validate_name",
  "GraphApp",
  "GraphApp.arun",
  "GraphApp.framework",
  "GraphApp.graph_kind",
  "GraphApp.invoke",
  "GraphApp.lineage",
  "GraphApp.run",
  "AgenticGraph",
  "AgenticGraph.add_agent_node",
  "AgenticGraph.add_node",
  "AgenticGraph.compile",
  "AgenticGraph.conditional_edges",
  "AgenticGraph.edge",
  "AgenticGraph.framework",
  "AgenticGraph.graph_kind",
  "AgenticGraph.native",
  "agent_node",
  "graph",
  "EvalReport",
  "EvalReport.cases",
  "EvalReport.failed",
  "EvalReport.lineage",
  "EvalReport.normalized",
  "EvalReport.ok",
  "EvalReport.pass_rate",
  "EvalReport.passed",
  "EvalReport.raise_if_failed",
  "EvalReport.reproducibility",
  "EvalReport.schema_version",
  "EvalReport.summary_text",
  "EvalReport.to_dict",
  "EvalReport.total",
  "EvalReport.validate_aggregates",
  "JudgeRubric",
  "JudgeRubric.certification_tool",
  "JudgeRubric.criteria",
  "JudgeRubric.deterministic_authority",
  "JudgeRubric.instructions",
  "JudgeRubric.threshold",
  "JudgeResult",
  "JudgeResult.certification_recorded",
  "JudgeResult.certification_tool",
  "JudgeResult.criteria",
  "JudgeResult.deterministic_authority",
  "JudgeResult.deterministic_validation_ok",
  "JudgeResult.execution_ok",
  "JudgeResult.framework",
  "JudgeResult.model",
  "JudgeResult.ok",
  "JudgeResult.provider",
  "JudgeResult.rationale",
  "JudgeResult.raw_criteria",
  "JudgeResult.raw_score",
  "JudgeResult.score",
  "JudgeResult.threshold",
  "JudgeResult.to_dict",
  "JudgeResult.usage",
  "JudgeResult.validate_verdict",
  "Evaluator",
  "Evaluator.evaluate",
  "Evaluator.evaluate_agent",
  "Evaluator.run",
  "run_eval",
  "AgenticEnvironment",
  "AgenticEnvironment.action_key",
  "AgenticEnvironment.astep",
  "AgenticEnvironment.close",
  "AgenticEnvironment.current_step",
  "AgenticEnvironment.episode_id",
  "AgenticEnvironment.episode_key",
  "AgenticEnvironment.graph",
  "AgenticEnvironment.history",
  "AgenticEnvironment.initial_memory",
  "AgenticEnvironment.keep_history",
  "AgenticEnvironment.lineage",
  "AgenticEnvironment.max_steps",
  "AgenticEnvironment.memory",
  "AgenticEnvironment.memory_key",
  "AgenticEnvironment.memory_updater",
  "AgenticEnvironment.name",
  "AgenticEnvironment.normalized",
  "AgenticEnvironment.observation_mapper",
  "AgenticEnvironment.records",
  "AgenticEnvironment.render",
  "AgenticEnvironment.render_mode",
  "AgenticEnvironment.reset",
  "AgenticEnvironment.reward_fn",
  "AgenticEnvironment.rng",
  "AgenticEnvironment.row_key",
  "AgenticEnvironment.seed",
  "AgenticEnvironment.state_factory",
  "AgenticEnvironment.step",
  "AgenticEnvironment.summary",
  "AgenticEnvironment.transition_fn",
  "build_agent_step_graph",
  "agent_output",
  "show_json",
  "show",
  "compose_result",
  "aws_environment_snapshot",
  "boto3_session_snapshot",
  "ollama_environment_snapshot",
  "openai_environment_snapshot",
  "vllm_environment_snapshot",
  "run_result_output",
  "run_result_view",
  "run_result_summary",
  "environment_summary",
  "eval_report_summary",
  "core",
  "providers",
  "integrations",
  "__version__"
])
EXPECTED_CHECKSUM = '01ad4a88d694ba0eb20ee7d71ec300ed1695ff4064c40514832cf7ad7a1290db'
EXPECTED_SCENARIOS = tuple([
  {
    "id": "runtime",
    "notebooks": [
      "providers/00_auto.ipynb",
      "providers/01_openai.ipynb",
      "providers/02_bedrock.ipynb",
      "providers/03_vllm.ipynb",
      "providers/04_ollama.ipynb",
      "core/00_runtime_scheduler.ipynb"
    ],
    "api_ids": [
      "runtime",
      "scheduler",
      "RuntimeConfig.describe"
    ]
  },
  {
    "id": "tool",
    "notebooks": [
      "core/01_tool.ipynb"
    ],
    "api_ids": [
      "tool",
      "Tool.run",
      "RunResult"
    ]
  },
  {
    "id": "skill",
    "notebooks": [
      "core/02_skills.ipynb"
    ],
    "api_ids": [
      "skill",
      "Skill.describe"
    ]
  },
  {
    "id": "agent",
    "notebooks": [
      "core/03_agent.ipynb",
      "core/04_results_lineage.ipynb",
      "core/08_single_agentic_system.ipynb",
      "frameworks/00_langgraph.ipynb",
      "frameworks/01_openai_agents.ipynb",
      "frameworks/02_aws_strands.ipynb"
    ],
    "api_ids": [
      "agent",
      "Agent.run",
      "RunResult"
    ]
  },
  {
    "id": "system",
    "notebooks": [
      "core/05_system.ipynb",
      "core/09_multi_agentic_system.ipynb"
    ],
    "api_ids": [
      "system",
      "AgenticSystem.run",
      "RunResult"
    ]
  },
  {
    "id": "graph",
    "notebooks": [
      "core/06_graph_native.ipynb",
      "core/10_multi_agent_graph.ipynb"
    ],
    "api_ids": [
      "graph",
      "GraphApp.run"
    ]
  },
  {
    "id": "environment",
    "notebooks": [
      "core/07_environment_eval.ipynb"
    ],
    "api_ids": [
      "environment",
      "AgenticEnvironment.reset",
      "AgenticEnvironment.step"
    ]
  },
  {
    "id": "eval",
    "notebooks": [
      "core/07_environment_eval.ipynb"
    ],
    "api_ids": [
      "eval",
      "Evaluator.run",
      "EvalReport"
    ]
  },
  {
    "id": "matrix",
    "notebooks": [
      "frameworks/03_provider_framework_matrix.ipynb"
    ],
    "api_ids": [
      "compatibility_matrix",
      "runtime",
      "framework",
      "Agent.run",
      "RunResult"
    ]
  },
  {
    "id": "api_contract",
    "notebooks": [
      "api/14_api_contract_matrix.ipynb"
    ],
    "api_ids": [
      "api_contract",
      "exercise_api"
    ]
  }
])
EXPECTED_SCENARIO_IDS = tuple(item['id'] for item in EXPECTED_SCENARIOS)
EXPECTED_SCENARIO_COUNT = 10
EXPECTED_EXPORT_COUNT = 89
EXPECTED_ENTRY_COUNT = 463

# %%
manifest = toolkit.api_contract()
assert tuple(manifest['ids']) == EXPECTED_API_IDS
assert manifest['checksum'] == EXPECTED_CHECKSUM
assert manifest['export_count'] == EXPECTED_EXPORT_COUNT
assert manifest['entry_count'] == EXPECTED_ENTRY_COUNT
public_scenarios = tuple(
    {
        'id': item['id'],
        'notebooks': item['notebooks'],
        'api_ids': item['api_ids'],
    }
    for item in manifest['scenarios']
)
assert public_scenarios == EXPECTED_SCENARIOS
assert tuple(manifest['scenario_ids']) == EXPECTED_SCENARIO_IDS
assert manifest['scenario_count'] == EXPECTED_SCENARIO_COUNT
toolkit.show({key: manifest[key] for key in ('schema_version', 'export_count', 'entry_count', 'scenario_count', 'checksum')})

# %% [markdown]
# ## Ejercicio completo
#
# Se resuelven todos los simbolos, miembros, campos y firmas sin invocar constructores ni producir efectos externos.

# %%
exercise = toolkit.exercise_api()
assert exercise['ok'] is True
assert exercise['count'] == EXPECTED_ENTRY_COUNT
assert tuple(item['id'] for item in exercise['results']) == EXPECTED_API_IDS
toolkit.show({'ok': exercise['ok'], 'verified_ids': exercise['count'], 'checksum': exercise['checksum']})

# %% [markdown]
# ## Resultado e interpretacion
#
# El resultado valido reporta `ok=True` y el mismo numero de IDs que el manifiesto. Cualquier diferencia es drift contractual y bloquea la release.
